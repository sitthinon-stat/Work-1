# %% [markdown]
# # SC 612 104 Essential Data Science
# ## คาบที่ 2: ตัวแปร, ชนิดข้อมูล, Operators, Type Conversion และ if/elif/else
#
# **ผู้สอน:** อ.ดร.พิชญา วิรัชโชติเสถียร (Pitchaya Wiratchotisatian)
# **ภาควิชาสถิติ คณะวิทยาศาสตร์ มหาวิทยาลัยขอนแก่น**
#
# ---
#
# ### เนื้อหาในคาบนี้
# 1. ตัวแปร (Variables)
# 2. ชนิดข้อมูล (Data Types): `int`, `float`, `str`, `bool`
# 3. Operators: คณิตศาสตร์, เปรียบเทียบ, ตรรกะ
# 4. Type Conversion
# 5. if / elif / else
# 6. แบบฝึกหัดท้ายคาบ (ลองทำเองดูนะ!)
#
# > 💡 **วิธีใช้ Notebook นี้:** อ่านคำอธิบาย รันโค้ดตัวอย่างทุกเซลล์ (กด `Shift + Enter`) แล้วลองแก้ค่าในโค้ดดูว่าผลลัพธ์เปลี่ยนยังไง ก่อนไปทำแบบฝึกหัด

# %% [markdown]
# ---
# ## 1. ตัวแปร (Variables)
#
# **ตัวแปร** คือ "ชื่อ" ที่เราใช้เก็บค่าข้อมูลไว้ในหน่วยความจำของคอมพิวเตอร์ เปรียบเหมือนกล่องที่มีป้ายชื่อติดไว้ — เราเก็บของ (ค่า) ไว้ในกล่อง แล้วเรียกของนั้นกลับมาใช้ผ่านชื่อกล่อง
#
# ### วิธีสร้างตัวแปรใน Python
#
# ใช้เครื่องหมาย `=` (เรียกว่า assignment operator) ในการกำหนดค่าให้ตัวแปร:
#
# ```python
# ชื่อตัวแปร = ค่า
# ```
#
# **ข้อสังเกต:** Python ไม่ต้องประกาศชนิดข้อมูลล่วงหน้า (ไม่เหมือน C/Java) — Python จะ "เดา" ชนิดข้อมูลให้เองจากค่าที่เราใส่

# %%
# สร้างตัวแปรเก็บชื่อ อายุ และส่วนสูง
name = "สมชาย"
age = 20
height = 175.5

print(name)
print(age)
print(height)
# Out:
# สมชาย
# 20
# 175.5

# %%
ฉัน = 10

# %%
ฉัน
# Out:
# 10

# %%
age
# Out:
# 20

# %% [markdown]
# ### กฎการตั้งชื่อตัวแปร (Naming Rules)
#
# | ทำได้ ✅ | ทำไม่ได้ ❌ |
# |---|---|
# | `my_age` | `2age` (ขึ้นต้นด้วยตัวเลขไม่ได้) |
# | `_score` | `my-age` (ห้ามมี `-`) |
# | `studentName` | `class` (ห้ามใช้ keyword ของ Python) |
# | `อายุ` (ภาษาไทยใช้ได้!) | `my age` (ห้ามมีเว้นวรรค) |
#
# **ข้อแนะนำ (Convention):** นิยมใช้ตัวพิมพ์เล็กและ `_` คั่นคำ เช่น `student_name` (เรียกว่า snake_case)

# %%
# ตัวอย่างชื่อตัวแปรที่ดีและไม่ดี

# ดี ✅
student_name = "มานี"
total_score = 85

# ใช้ได้ แต่ไม่ใช่ convention ที่นิยม
StudentName = "มานี"   # นิยมใช้กับชื่อ class มากกว่า

print(student_name, total_score)
# Out:
# มานี 85

# %% [markdown]
# ### การกำหนดค่าหลายตัวแปรพร้อมกัน
#
# Python อนุญาตให้กำหนดค่าหลายตัวแปรในบรรทัดเดียวได้

# %%
# กำหนดค่าหลายตัวแปรพร้อมกัน
x, y, z = 1, 2, 3
print(x, y, z)

# กำหนดค่าเดียวกันให้หลายตัวแปร
a = b = c = 0
print(a, b, c)
# Out:
# 1 2 3
# 0 0 0

# %% [markdown]
# ### ลองเปลี่ยนค่าตัวแปร
#
# ตัวแปรใน Python เปลี่ยนค่าได้ตลอดเวลา (เพราะเป็นภาษาที่ใช้ dynamic typing)

# %%
score = 50
print("ก่อนเปลี่ยน:", score)

score = 80  # เปลี่ยนค่า
print("หลังเปลี่ยน:", score)

score = "ผ่าน"  # เปลี่ยนชนิดข้อมูลเลย!
print("เปลี่ยนชนิดข้อมูล:", score)
# Out:
# ก่อนเปลี่ยน: 50
# หลังเปลี่ยน: 80
# เปลี่ยนชนิดข้อมูล: ผ่าน

# %% [markdown]
# ---
# ## 2. ชนิดข้อมูล (Data Types)
#
# Python มีชนิดข้อมูลพื้นฐานหลายแบบ แต่ที่ใช้บ่อยที่สุด 4 แบบคือ:
#
# | ชนิดข้อมูล | ชื่อเต็ม | ตัวอย่าง | ใช้เก็บอะไร |
# |---|---|---|---|
# | `int` | Integer | `10`, `-5`, `0` | เลขจำนวนเต็ม |
# | `float` | Floating point | `3.14`, `-0.5` | เลขทศนิยม |
# | `str` | String | `"สวัสดี"`, `'Hi'` | ข้อความ |
# | `bool` | Boolean | `True`, `False` | ค่าจริง/เท็จ |
#
# https://www.w3schools.com/python/python_datatypes.asp
#
# ใช้ฟังก์ชัน `type()` เพื่อตรวจสอบชนิดข้อมูลของตัวแปรได้

# %%
# ตรวจสอบชนิดข้อมูลด้วย type()
a = 10
b = 3.14
c = "Data Science"
d = True

print(type(a))   # int
print(type(b))   # float
print(type(c))   # str
print(type(d))   # bool
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ### 2.1 int (จำนวนเต็ม)
#
# ใช้เก็บเลขจำนวนเต็ม ทั้งบวกและลบ ไม่มีจุดทศนิยม

# %%
# ตัวอย่าง int
num_students = 45
temperature_celsius = -2
year = 2569

print(num_students, temperature_celsius, year)
print(type(num_students))
# Out:
# 45 -2 2569
# <class 'int'>

# %% [markdown]
# ### 2.2 float (ทศนิยม)
#
# ใช้เก็บเลขที่มีจุดทศนิยม — แม้จะใส่ `.0` ก็ถือเป็น float ทันที

# %%
# ตัวอย่าง float
gpa = 3.75
pi_value = 3.14159
price = 99.0   # มี .0 ก็เป็น float แล้ว

print(gpa, pi_value, price)
print(type(price))
# Out:
# 3.75 3.14159 99.0
# <class 'float'>

# %% [markdown]
# ### 2.3 str (ข้อความ)
#
# ใช้เก็บข้อความ ครอบด้วยเครื่องหมายคำพูดเดี่ยว `'...'` หรือคู่ `"..."` ก็ได้ — ผลลัพธ์เหมือนกัน

# %%
# ตัวอย่าง str
greeting = "สวัสดีค่ะ"
course_code = 'SC 612 104'

print(greeting)
print(course_code)

# เชื่อมข้อความด้วย +
full_text = greeting + " " + course_code
print(full_text)

# str ความยาวหลายบรรทัด ใช้ '''...''' หรือ """..."""
message = """บรรทัดที่ 1
บรรทัดที่ 2"""
print(message)
# Out:
# สวัสดีค่ะ
# SC 612 104
# สวัสดีค่ะ SC 612 104
# บรรทัดที่ 1
# บรรทัดที่ 2

# %% [markdown]
# ### 2.4 bool (ค่าจริง/เท็จ)
#
# มีได้แค่ 2 ค่า: `True` หรือ `False` (ตัวอักษรตัวแรกต้องพิมพ์ใหญ่เสมอ) มักเกิดจากการเปรียบเทียบค่า

# %%
# ตัวอย่าง bool
is_student = True
is_raining = False

print(is_student, is_raining)
print(type(is_student))

# bool มักเกิดจากการเปรียบเทียบ
score = 75
is_passed = score >= 50
print("ผ่านไหม:", is_passed)
# Out:
# True False
# <class 'bool'>
# ผ่านไหม: True

# %% [markdown]
# ### 💡 เกร็ดความรู้: f-string — วิธี print ที่อ่านง่ายและนิยมที่สุด
#
# เวลาต้องการแสดงข้อความผสมกับค่าตัวแปร ใช้ `f"..."` แล้วใส่ตัวแปรใน `{}` จะอ่านง่ายกว่าการ `+` ข้อความเข้าด้วยกันมาก

# %%
name = "มานี"
age = 20
gpa = 3.75

# วิธีเก่า (เชื่อมด้วย +) — ต้องแปลงชนิดข้อมูลเองและอ่านยาก
print("ชื่อ " + name + " อายุ " + str(age) + " ปี")

# วิธีใหม่ (f-string) — อ่านง่าย ไม่ต้องแปลงชนิดข้อมูลเอง
print(f"ชื่อ {name} อายุ {age**2} ปี เกรดเฉลี่ย {gpa}")
# Out:
# ชื่อ มานี อายุ 20 ปี
# ชื่อ มานี อายุ 400 ปี เกรดเฉลี่ย 3.75

# %% [markdown]
# Format String: https://www.w3schools.com/python/python_string_formatting.asp

# %%
price = 19.999
quantity = 5
item = "Laptop"

# กำหนดทศนิยม 2 ตำแหน่งสำหรับ float
print(f"ราคาต่อชิ้น: {price:.5f} บาท")

# จัดตำแหน่งข้อความและตัวเลข
print(f"สินค้า: {item:<10} | จำนวน: {quantity:>5}")

# แสดงผลเป็นเปอร์เซ็นต์
progress = 0.75
print(f"ความคืบหน้า: {progress:.1%}")

# แสดงผลโดยมีคอมม่าคั่นหลักพัน
large_number = 1234567
print(f"ตัวเลขขนาดใหญ่: {large_number:,}")
# Out:
# ราคาต่อชิ้น: 19.99900 บาท
# สินค้า: Laptop     | จำนวน:     5
# ความคืบหน้า: 75.0%
# ตัวเลขขนาดใหญ่: 1,234,567

# %% [markdown]
# อย่าลืมมาเขียนใหม่

# %% [markdown]
# ---
# ## 3. Operators (ตัวดำเนินการ)

# %% [markdown]
# แบ่งเป็น 3 กลุ่มหลักที่ต้องรู้จัก: **คณิตศาสตร์**, **เปรียบเทียบ**, และ **ตรรกะ**
#
# ### 3.1 Arithmetic Operators (ตัวดำเนินการทางคณิตศาสตร์)
#
# | Operator | ความหมาย | ตัวอย่าง | ผลลัพธ์ |
# |---|---|---|---|
# | `+` | บวก | `5 + 3` | `8` |
# | `-` | ลบ | `5 - 3` | `2` |
# | `*` | คูณ | `5 * 3` | `15` |
# | `/` | หาร (ได้ float เสมอ) | `5 / 2` | `2.5` |
# | `//` | หารปัดเศษทิ้ง (floor division) | `5 // 2` | `2` |
# | `%` | หารเอาเศษ (modulo) | `5 % 2` | `1` |
# | `**` | ยกกำลัง | `5 ** 2` | `25` |

# %%
a = 17
b = 5

print("a + b  =", a + b)
print("a - b  =", a - b)
print("a * b  =", a * b)
print("a / b  =", a / b)    # หารปกติ ได้ float
print("a // b =", a // b)   # หารปัดเศษทิ้ง
print("a % b  =", a % b)    # เศษจากการหาร
print("a ** b =", a ** b)   # a ยกกำลัง b
# Out:
# a + b  = 22
# a - b  = 12
# a * b  = 85
# a / b  = 3.4
# a // b = 3
# a % b  = 2
# a ** b = 1419857

# %%
a=33
b=17
c=77
d=52

print()

# %% [markdown]
# **จุดที่ต้องระวัง:** `/` กับ `//` ให้ผลต่างกัน!
# - `/` คือหารแบบปกติ ผลลัพธ์เป็น `float` เสมอ แม้จะหารลงตัว
# - `//` คือหารแบบปัดเศษทิ้ง (floor) ผลลัพธ์เป็น `int` ถ้า input เป็น int ทั้งคู่
#
# `%` (modulo) มีประโยชน์มากในการเช็คว่าเลขคู่/เลขคี่ หรือเช็คตัวหารร่วม

# %%
# ตัวอย่างการใช้ % เช็คเลขคู่/เลขคี่
number = 17

if number % 2 == 0:
    print(f"{number} เป็นเลขคู่")
else:
    print(f"{number} เป็นเลขคี่")

# %% [markdown]
# #### ลำดับการคำนวณ (Order of Operations / PEMDAS)
#
# เมื่อมีตัวดำเนินการหลายตัวอยู่ในนิพจน์เดียว Python จะคำนวณตามลำดับความสำคัญ (Precedence)
# เหมือนที่เราคุ้นเคยในคณิตศาสตร์ ซึ่งเรียกย่อว่า PEMDAS/BODMAS
#
# - **P**arentheses (วงเล็บ `()`) — ทำในวงเล็บก่อนเสมอ
# - **E**xponents (เลขยกกำลัง `**`) — ทำเป็นลำดับถัดมา
# - **M**ultiplication (คูณ `*`) และ **D**ivision (หาร `/`, `//`, `%`) — มีความสำคัญเท่ากัน ทำจากซ้ายไปขวา
# - **A**ddition (บวก `+`) และ **S**ubtraction (ลบ `-`) — มีความสำคัญเท่ากัน ทำจากซ้ายไปขวา
#
# การใช้วงเล็บ `()` สามารถบังคับลำดับการคำนวณให้เป็นไปตามที่เราต้องการได้

# %% [markdown]
# --- ตัวอย่าง PEMDAS ---

# %%
# ไม่มีวงเล็บ: คูณ/หาร ทำก่อน บวก/ลบ
# 10 + 5 * 2 => 10 + 10 => 20
result1 = 10 + 5 * 2
print(f"10 + 5 * 2 = {result1}")
# Out:
# 10 + 5 * 2 = 20

# %%
# มีวงเล็บ: ทำในวงเล็บก่อน
# (10 + 5) * 2 => 15 * 2 => 30
result2 = (10 + 5) * 2
print(f"(10 + 5) * 2 = {result2}")

# %%
# ตัวอย่างที่ซับซ้อนขึ้น:
result3 = 2 ** 3 + 6 / 3 - 1
print(f"2 ** 3 + 6 / 3 - 1 = {result3}")
# Out:
# 2 ** 3 + 6 / 3 - 1 = 9.0

# %%
# ใช้วงเล็บเพื่อเปลี่ยนลำดับ
result4 = 2 ** (3 + 6) / 3 - 1
print(f"2 ** (3 + 6) / 3 - 1 = {result4}")
# Out:
# 2 ** (3 + 6) / 3 - 1 = 169.66666666666666

# %%
print("\nข้อควรจำ: เมื่อมี operator ความสำคัญเท่ากัน ให้ทำจากซ้ายไปขวา")
# 10 / 2 * 5
result5 = 10 / 2 * 5
print(f"10 / 2 * 5 = {result5}")

# %%
# 10 * 5 / 2
result6 = 10 * 5 / 2
print(f"10 * 5 / 2 = {result6}")

# %% [markdown]
# ### 3.2 Comparison Operators (ตัวดำเนินการเปรียบเทียบ)
#
# ผลลัพธ์จากการเปรียบเทียบเป็น `bool` เสมอ (`True` หรือ `False`)
#
# | Operator | ความหมาย | ตัวอย่าง | ผลลัพธ์ |
# |---|---|---|---|
# | `==` | เท่ากับ | `5 == 5` | `True` |
# | `!=` | ไม่เท่ากับ | `5 != 3` | `True` |
# | `>` | มากกว่า | `5 > 3` | `True` |
# | `<` | น้อยกว่า | `5 < 3` | `False` |
# | `>=` | มากกว่าหรือเท่ากับ | `5 >= 5` | `True` |
# | `<=` | น้อยกว่าหรือเท่ากับ | `5 <= 3` | `False` |
#
# **⚠️ ข้อผิดพลาดที่พบบ่อย:** `=` ใช้กำหนดค่า ส่วน `==` ใช้เปรียบเทียบ — สลับกันใช้ไม่ได้!

# %%
x = 10
y = 20

print(x == y)   # False เพราะ 10 ไม่เท่ากับ 20
print(x != y)   # True เพราะ 10 ไม่เท่ากับ 20 จริง
print(x < y)    # True
print(x >= 10)  # True เพราะ 10 เท่ากับ 10

# %%
3== 3.000000001
# Out:
# False

# %% [markdown]
# ### 3.3 Logical Operators (ตัวดำเนินการตรรกะ)
#
# ใช้รวมเงื่อนไขหลายๆ อันเข้าด้วยกัน
#
# | Operator | ความหมาย | ตัวอย่าง |
# |---|---|---|
# | `and` | จริงทั้งคู่ จึงเป็นจริง | `True and False` → `False` |
# | `or` | จริงอย่างน้อยหนึ่ง จึงเป็นจริง | `True or False` → `True` |
# | `not` | กลับค่าตรงข้าม | `not True` → `False` |

# %%
age = 20
has_id_card = True

# ต้องอายุ >= 18 AND มีบัตรประชาชน จึงเข้าได้
can_enter = (age >= 18) and (has_id_card == True)
print("เข้าได้ไหม:", can_enter)

# ตัวอย่าง or
is_weekend = False
is_holiday = True
can_rest = is_weekend or is_holiday
print("วันนี้พักได้ไหม:", can_rest)

# ตัวอย่าง not
is_raining = False
print("ไม่ฝนตกใช่ไหม:", not is_raining)

# %% [markdown]
# ---
# ## 4. Type Conversion / Casting(การแปลงชนิดข้อมูล)
#
# บางครั้งข้อมูลที่ได้มาไม่ใช่ชนิดที่เราต้องการ เช่น รับค่าจากผู้ใช้มาเป็น `str` เสมอ แต่เราต้องเอาไปคำนวณเป็นตัวเลข — ต้องแปลงชนิดข้อมูลก่อน
#
# | ฟังก์ชัน | แปลงเป็น | ตัวอย่าง |
# |---|---|---|
# | `int()` | จำนวนเต็ม | `int("5")` → `5` |
# | `float()` | ทศนิยม | `float("3.14")` → `3.14` |
# | `str()` | ข้อความ | `str(5)` → `"5"` |
# | `bool()` | จริง/เท็จ | `bool(1)` → `True` |

# %%
# str -> int / float
age_text = "20"
age_number = int(age_text)
print(age_number + 5)   # บวกได้แล้วเพราะเป็น int

price_text = "99.50"
price_number = float(price_text)
print(price_number * 2)

# int/float -> str (ใช้บ่อยตอน + ข้อความ)
score = 95
message = "คะแนนของคุณคือ " + str(score)
print(message)

# %% [markdown]
# **⚠️ ข้อผิดพลาดที่พบบ่อย:** ถ้า string ไม่ใช่ตัวเลข จะแปลงไม่ได้ และ Python จะแจ้ง error แบบ `ValueError`

# %%
# ทดลองรันเซลล์นี้ดู จะเกิด error อะไร?
text = "สวัสดี"
# number = int(text)   # ลบ # ข้างหน้าแล้วรันดู จะเห็น ValueError

# วิธีป้องกัน: เช็คก่อนแปลงด้วย .isdigit()
text2 = "123"
if text2.isdigit():
    print(int(text2) + 1)
else:
    print("แปลงเป็นตัวเลขไม่ได้")
# Out:
# 124

# %%
# bool <-> int: True เท่ากับ 1, False เท่ากับ 0
print(int(True))    # 1
print(int(False))   # 0
print(bool(0))       # False
print(bool(1))       # True
print(bool(99))      # True -- ตัวเลขที่ไม่ใช่ 0 ทั้งหมดเป็น True!
print(bool(""))      # False -- string ว่างเป็น False
print(bool("hello")) # True -- string ที่ไม่ว่างเป็น True

# %% [markdown]
# ---
# ## 5. if / elif / else (การเขียนเงื่อนไข)
#
# ใช้ตัดสินใจว่าโปรแกรมควรทำอะไร ขึ้นอยู่กับเงื่อนไขที่กำหนด
#
# ### โครงสร้างพื้นฐาน
#
# ```python
# if เงื่อนไข1:
#     # ทำสิ่งนี้ ถ้าเงื่อนไข1 เป็นจริง
# elif เงื่อนไข2:
#     # ทำสิ่งนี้ ถ้าเงื่อนไข1 ไม่จริง แต่เงื่อนไข2 เป็นจริง
# else:
#     # ทำสิ่งนี้ ถ้าไม่มีเงื่อนไขไหนเป็นจริงเลย
# ```
#
# **⚠️ จุดสำคัญที่สุดของ Python:** ต้องมี **เครื่องหมาย `:`** ท้ายบรรทัดเงื่อนไข และ**บรรทัดถัดไปต้องเยื้อง (indent)** ด้วย Tab หรือเว้นวรรค 4 ครั้ง — Python ใช้การเยื้องบรรทัดแทนวงเล็บปีกกา `{}` แบบภาษาอื่น

# %%
# if แบบพื้นฐาน
temperature = 35

if temperature > 30:
    print("วันนี้อากาศร้อนมาก")

# %%
# if-else
score = 45

if score >= 50:
    print("ผ่าน")
else:
    print("ไม่ผ่าน")

# %%
# if-elif-else: ใช้ตัดเกรดจากคะแนน
score = 78

if score >= 80:
    grade = "A"
elif score >= 70:
    grade = "B"
elif score >= 60:
    grade = "C"
elif score >= 50:
    grade = "D"
else:
    grade = "F"

print(f"คะแนน {score} ได้เกรด {grade}")

# %% [markdown]
# ### เงื่อนไขซ้อนกัน (Nested if) และเงื่อนไขซับซ้อน
#
# สามารถใส่ `if` ซ้อนใน `if` ได้ และรวมหลายเงื่อนไขด้วย `and` / `or`

# %%
# nested if: เช็คสมัครสมาชิกแบบมีเงื่อนไขซ้อน
age = 16
has_parent_consent = True

if age >= 18:
    print("สมัครได้เลย")
else:
    if has_parent_consent:
        print("อายุไม่ถึง แต่มีผู้ปกครองยินยอม สมัครได้")
    else:
        print("สมัครไม่ได้ ต้องรอผู้ปกครองยินยอมก่อน")

# %%
# รวมเงื่อนไขด้วย and / or ในบรรทัดเดียว (อ่านง่ายกว่า nested if)
age = 16
has_parent_consent = True

if age >= 18 or (age >= 13 and has_parent_consent):
    print("สมัครได้")
else:
    print("สมัครไม่ได้")

# %% [markdown]
# ---
# ## 🧪 แบบฝึกหัดท้ายคาบ
#
# > ลองทำเองในเซลล์ที่เตรียมไว้ด้านล่างแต่ละข้อ ไม่มีเฉลยให้ — ถ้าไม่แน่ใจให้ลองรันดูผลลัพธ์ หรือถามอาจารย์/เพื่อนได้เลย
#
# ### ข้อ 1: ตัวแปรและชนิดข้อมูล
# สร้างตัวแปร 4 ตัวเก็บข้อมูลเกี่ยวกับตัวเอง: ชื่อ (str), อายุ (int), ส่วนสูงเป็นเมตร (float), และสถานะว่าเป็นนักศึกษาหรือไม่ (bool) จากนั้น print ออกมาด้วย f-string ในรูปแบบ:
#
# ```
# ชื่อ ... อายุ ... ปี ส่วนสูง ... เมตร เป็นนักศึกษา: ...
# ```

# %%
# เขียนคำตอบข้อ 1 ที่นี่
name = "sitthinon chueakuna"
age = 20
hight = 173.5
is_student=True
is_notstudent=False

print(f"ชื่อ {name} อายุ {age} ส่วนสูง {hight} เมตร เป็นนักศึกษา {is_student}")
# Out:
# ชื่อ sitthinon chueakuna อายุ 20 ส่วนสูง 173.5 เมตร เป็นนักศึกษา True

# %% [markdown]
# ### ข้อ 2: Operators
# กำหนด `a = 23` และ `b = 4` จงคำนวณและ print ผลลัพธ์ต่อไปนี้:
# - ผลรวมของ a และ b
# - ผลหารแบบปัดเศษทิ้งของ a หาร b
# - เศษที่เหลือจากการหาร a ด้วย b
# - a ยกกำลัง 2

# %%
# เขียนคำตอบข้อ 2 ที่นี่
a = 23
b = 4
print("a+b=",a+b)
print("a//b=",a//b)
print("a%b=",a%b)
print("a**b=",a**b)
# Out:
# a+b= 27
# a//b= 5
# a%b= 3
# a**b= 279841

# %% [markdown]
# ### ข้อ 3: Type Conversion
# มีตัวแปร `input_text = "150"` ซึ่งเป็น string จงแปลงให้เป็น int แล้วบวกด้วย 50 และ print ผลลัพธ์ออกมา

# %%
input_text="150"
ip=int(input_text)
print(ip+50)
# Out:
# 200

# %% [markdown]
# ### ข้อ 4: if/elif/else — ตรวจ BMI
# สูตรคำนวณ BMI คือ `น้ำหนัก(kg) / (ส่วนสูง(m) ** 2)`
#
# จงเขียนโค้ดที่:
# 1. กำหนดตัวแปร `weight = 65` (kg) และ `height = 1.70` (m)
# 2. คำนวณค่า BMI
# 3. ใช้ if/elif/else แปลผลตามเกณฑ์นี้:
#    - BMI < 18.5 → "น้ำหนักน้อย"
#    - 18.5 ≤ BMI < 23 → "น้ำหนักปกติ"
#    - 23 ≤ BMI < 25 → "น้ำหนักเกิน"
#    - BMI ≥ 25 → "อ้วน"
# 4. print ค่า BMI (ทศนิยม 2 ตำแหน่ง) และผลแปลความหมาย
#
# 💡 Hint: ใช้ `round(ค่า, 2)` เพื่อปัดทศนิยม 2 ตำแหน่ง

# %%
# เขียนคำตอบข้อ 4 ที่นี่
weight =79.9
height =1.73
BMI = weight / height**2
print(f"ค่า BMI ของคุณคือ  {BMI:.2f}")

if BMI < 18.5 :
    BMI = "น้ำหนักน้อย"
elif 18.5 <= BMI < 23 :
    BMI = "น้ำหนักปกติ"
elif 23 <= BMI < 25 :
    BMI = "น้ำหนักเกิน"
elif BMI >=25 :
    BMI = "อ้วน"
print(f"เกณฑ์ {BMI}")
# Out:
# ค่า BMI ของคุณคือ  26.70
# เกณฑ์ อ้วน

# %% [markdown]
# ### ข้อ 5: ท้าทายเพิ่มเติม (Challenge)
# เขียนโปรแกรมเช็คว่าปี (year) ที่กำหนดเป็น**ปีอธิกสุรทิน** (leap year) หรือไม่ โดยใช้เงื่อนไข:
# - หารด้วย 4 ลงตัว **และ** (หารด้วย 100 ไม่ลงตัว **หรือ** หารด้วย 400 ลงตัว) → เป็นปีอธิกสุรทิน
#
# ทดสอบกับปี 2024, 2023, 2000, 1900

# %%
# เขียนคำตอบข้อ 5 ที่นี่
year1,year2,year3,year4= 2024,2023,2000,1900
year1result1,year2result1,year3result1,year4result1=year1%4,year2%4,year3%4,year4%4 #หารด้วย4
year1result2,year2result2,year3result2,year4result2=year1%100,year2%100,year3%100,year4%100 #หารด้วย100
year1result3,year2result3,year3result3,year4result3=year1%400,year2%400,year3%400,year4%400 #หารด้วย400

if year1result1==0 and (year1result2!=0 or year1result3==0):
  print(f"ปี{year1}เป็นปีอธิกสุรทิน")
elif  year1result1!=0 and (year1result2!=0 or year1result3!=0):
  print(f"ปี{year1}ไม่เป็นปีอธิกสุรทิน")

if year2result1==0 and  (year2result2!=0 or year2result3==0):
  print(f"ปี{year2}เป็นปีอธิกสุรทิน")
elif  year2result1!=0 and (year2result2==0 or year2result3!=0):
  print(f"ปี{year2}ไม่เป็นปีอธิกสุรทิน")

if year3result1==0 and  (year3result2!=0 or year3result3==0):
  print(f"ปี{year3}เป็นปีอธิกสุรทิน")
elif  year3result1!=0 and (year3result2!=0 or year3result3==0):
  print(f"ปี{year3}ไม่เป็นปีอธิกสุรทิน")

if year4result1==0 and  (year4result2!=0 or year4result3==0) :
  print(f"ปี{year4}เป็นปีอธิกสุรทิน")
elif  year4result1!=0 or year4result2!=0 or year4result3!=0 :
  print(f"ปี{year4}ไม่เป็นปีอธิกสุรทิน")
# Out:
# ปี2024เป็นปีอธิกสุรทิน
# ปี2023ไม่เป็นปีอธิกสุรทิน
# ปี2000เป็นปีอธิกสุรทิน
# ปี1900ไม่เป็นปีอธิกสุรทิน

# %%
year4=1900
year4result1=year4%4
year4result2=year4%100
year4result3=year4%400

if year4result1==0 and  (year4result2!=0 or year4result3==0):
  print(f"ปี{year4}เป็นปีอธิกสุรทิน")
elif  year4result1!=0:
  print(f"ปี{year4}ไม่เป็นปีอธิกสุรทิน")

# %%
if :
  print(f"ปี{year2}เป็นปีอธิกสุรทิน")
elif  :
  print(f"ปี{year2}ไม่เป็นปีอธิกสุรทิน")

if :
  print(f"ปี{year3}เป็นปีอธิกสุรทิน")
elif  :
  print(f"ปี{year3}ไม่เป็นปีอธิกสุรทิน")

if :
  print(f"ปี{year4}เป็นปีอธิกสุรทิน")
elif  :
  print(f"ปี{year4}ไม่เป็นปีอธิกสุรทิน")

# %% [markdown]
# ---
# ## 🔗 เชื่อม Colab กับ GitHub
#
# เก็บ Notebook นี้ขึ้น GitHub เพื่อ backup งานและสร้าง portfolio ของตัวเอง ทำได้ 2 วิธี:
#
# ### วิธีที่ 1: เซฟจาก Colab ขึ้น GitHub ตรงๆ (ง่ายที่สุด)
#
# 1. ใน Colab ไปที่เมนู **File → Save a copy in GitHub**
# 2. ครั้งแรกจะให้ login และ authorize Google Colab ให้เข้าถึง GitHub account ของคุณ
# 3. เลือก repository ปลายทาง (หรือสร้าง repo ใหม่ได้จากหน้านี้เลย)
# 4. ตั้งชื่อไฟล์และ commit message แล้วกด **OK**
# 5. ไฟล์ `.ipynb` จะถูก push ขึ้น GitHub repo ที่เลือกทันที
#
# ### วิธีที่ 2: เปิด Notebook จาก GitHub เข้า Colab
#
# 1. ไปที่ **colab.research.google.com**
# 2. เลือกแท็บ **GitHub**
# 3. พิมพ์ชื่อ repo หรือ URL ของ Notebook บน GitHub
# 4. เลือกไฟล์ `.ipynb` ที่ต้องการเปิด
#
# ### วิธีที่ 3: ใช้ Git ผ่าน Terminal (สำหรับคนที่อยากฝึกใช้ Git จริงจัง)
#
# ```bash
# git clone https://github.com/<username>/<repo-name>.git
# cd <repo-name>
# git add notebook.ipynb
# git commit -m "เพิ่ม notebook คาบที่ 2"
# git push origin main
# ```
#
# > 💡 **Tip:** การเก็บ Notebook ทุกคาบไว้ใน GitHub repo เดียว (เช่น `SC612104-coursework`) จะกลายเป็น portfolio ที่โชว์ progress การเรียนของคุณได้ดีมาก ลองทำเป็นกิจวัตรหลังจบทุกคาบดู
#
# สอนเสร็จแล้วจะให้ส่งด้วย!
